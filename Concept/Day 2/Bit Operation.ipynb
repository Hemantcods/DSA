# %%
# Decimal to Binary
bin(6)[2:]
# Out:
# '110'

# %%
# binary to decimal
binary_6="110"
int(binary_6,2)
# Out:
# 6

# %%
# bitwise AND
5 & 6
# Out:
# 4

# %%
# Bitwise OR
5 | 7
# Out:
# 7

# %%
# Bitwise XOR
5 ^ 7
# Out:
# 2

# %%
# Bitwise NOT
~5
# Out:
# -6

# %%
# Left Shift
5 << 2
# Out:
# 20

# %%
# Arithmetic (signed) Right Shift
5>>1
# Out:
# 2

# %%
# Hexa decimal
0-0
1-1
2-2
...
10-A
11-B
...
15-F
